# %% [markdown]
# # Introduction to Synthetic Aperture Radar Using Python and MATLAB
#
# ## by Andy Harrison - &copy; Artech House 2022
#
# ---
#
# ## Example 2.12.5 Stripmap SAR Pulse Repetition Freuqency
# ---

# %% [markdown]
# **Import modules**

# %%
# %matplotlib inline

import numpy as np

from scipy.constants import speed_of_light

from matplotlib import pyplot as plt

# %% [markdown]
# **Set the velocity (m/s)**

# %%
velocity = np.linspace(50, 2000)

# %% [markdown]
# **Set the cross range resolution (m)**

# %%
cross_range_resolution = 3.5

# %% [markdown]
# **Calculate the antenna azimuth dimension (m)**

# %%
Da = 2 * cross_range_resolution

# %% [markdown]
# **Set the unambiguous range (m)**

# %%
unambiguous_range = 200e3;

# %% [markdown]
# **Calculate the upper limit (Hz)**

# %%
prf_upper_limit = speed_of_light / (2 * unambiguous_range) * np.ones_like(velocity)

# %% [markdown]
# **Calculate the lower limit (Hz)**

# %%
prf_lower_limit = 2 * velocity / Da

# %% [markdown]
# **Plot the upper and lower limtis**

# %%
# Set the figure size

plt.rcParams["figure.figsize"] = (12, 9)


# Upper and lower limits

plt.plot(velocity, prf_upper_limit, linewidth=2, label='Upper Limit')

plt.plot(velocity, prf_lower_limit, linewidth=2, label='Lower Limit')



# Set the plot title and labels

plt.title('Stripmap PRF Upper and Lower Limits', size=18)

plt.xlabel('Platform Velocity (m/s)', size=16)

plt.ylabel('Pulse Repetition Frequency (Hz)', size=16)



# Set the tick label size

plt.tick_params(labelsize=16)



# Turn on the grid

plt.grid(linestyle=':', linewidth=0.5)



# Display the legend

plt.legend(loc='best')



# Display the figure

plt.show()
